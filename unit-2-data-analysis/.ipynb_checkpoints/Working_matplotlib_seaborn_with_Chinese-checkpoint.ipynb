# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %% [markdown]
# ##  尋找matplotlib中可用字體
# 註：需知道中文字體的英文名稱

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'cmss10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'DejaVu Serif Display',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'cmb10',
#  'cmmi10',
#  'STIXGeneral',
#  'cmtt10',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXNonUnicode',
#  'Segoe Fluent Icons',
#  'Consolas',
#  'High Tower Text',
#  'Constantia',
#  'Nirmala UI',
#  'MS Gothic',
#  'Consolas',
#  'Old English Text MT',
#  'Segoe UI',
#  'Segoe UI',
#  'Times New Roman',
#  'Book Antiqua',
#  'Microsoft New Tai Lue',
#  'Segoe UI',
#  'Parchment',
#  'Trebuchet MS',
#  'Wingdings',
#  'Book Antiqua',
#  'Segoe Print',
#  'Trebuchet MS',
#  'Calibri',
#  'Ink Free',
#  'Magneto',
#  'Garamond',
#  'Comic Neue',
#  'MingLiU-ExtB',
#  'Tempus Sans ITC',
#  'Consolas',
#  'Footlight MT Light',
#  'Trebuchet MS',
#  'Leelawadee',
#  'Gadugi',
#  'Palatino Linotype',
#  'Juice ITC',
#  'Californian FB',
#  'Vivaldi',
#  'Lucida Bright',
#  'Wingdings 3',
#  'Calibri',
#  'Corbel',
#  'Ravie',
#  'Segoe Script',
#  'Cambria',
#  'xkcd',
#  'Garamond',
#  'Arial',
#  'Book Antiqua',
#  'Bahnschrift',
#  'Segoe Print',
#  'SimSun',
#  'Ebrima',
#  'Lucida Fax',
#  'Arial',
#  'Verdana',
#  'Verdana',
#  'Comic Neue',
#  'Berlin Sans FB',
#  'Microsoft Tai Le',
#  'Calibri',
#  'Cooper Black',
#  'Yu Gothic',
#  'Nirmala UI',
#  'Book Antiqua',
#  'Arial',
#  'Brush Script MT',
#  'Californian FB',
#  'Segoe UI Symbol',
#  'Verdana',
#  'Segoe UI',
#  'Poor Richard',
#  'Lucida Console',
#  'Lucida Fax',
#  'Comic Neue',
#  'DFKai-SB',
#  'Constantia',
#  'Kunstler Script',
#  'Bookman Old Style',
#  'Myanmar Text',
#  'Palatino Linotype',
#  'High Tower Text',
#  'Constantia',
#  'Britannic Bold',
#  'Modern No. 20',
#  'Tahoma',
#  'Calibri',
#  'Comic Neue',
#  'Microsoft Uighur',
#  'Segoe UI',
#  'Sitka',
#  'Malgun Gothic',
#  'Bookman Old Style',
#  'Segoe UI',
#  'Segoe UI Emoji',
#  'Microsoft YaHei',
#  'Mongolian Baiti',
#  'Microsoft New Tai Lue',
#  'Cambria',
#  'Lucida Sans Unicode',
#  'Lucida Fax',
#  'Courier New',
#  'Harlow Solid Italic',
#  'Wingdings 2',
#  'Courier New',
#  'Baskerville Old Face',
#  'MS Outlook',
#  'Georgia',
#  'Times New Roman',
#  'Bernard MT Condensed',
#  'Yu Gothic',
#  'Cambria',
#  'Microsoft Yi Baiti',
#  'Century Gothic',
#  'Century Gothic',
#  'Leelawadee UI',
#  'Kristen ITC',
#  'Segoe UI',
#  'Impact',
#  'Candara',
#  'Cambria',
#  'Jokerman',
#  'Symbol',
#  'MS Reference Specialty',
#  'Lucida Bright',
#  'Myanmar Text',
#  'Bookman Old Style',
#  'xkcd Script',
#  'Garamond',
#  'Times New Roman',
#  'Californian FB',
#  'MS Reference Sans Serif',
#  'Corbel',
#  'Courier New',
#  'Candara',
#  'Leelawadee',
#  'Ebrima',
#  'Wide Latin',
#  'Chiller',
#  'Microsoft Tai Le',
#  'Colonna MT',
#  'Comic Sans MS',
#  'Leelawadee UI',
#  'Onyx',
#  'Georgia',
#  'Vladimir Script',
#  'Century Gothic',
#  'Informal Roman',
#  'Bell MT',
#  'Segoe UI',
#  'Bell MT',
#  'Segoe UI',
#  'Nirmala UI',
#  'Arial',
#  'Courier New',
#  'Microsoft JhengHei',
#  'Sans Serif Collection',
#  'Franklin Gothic Medium',
#  'Comic Neue',
#  'Segoe MDL2 Assets',
#  'Lucida Calligraphy',
#  'Berlin Sans FB',
#  'Yu Gothic',
#  'Candara',
#  'Georgia',
#  'Bodoni MT',
#  'Lucida Handwriting',
#  'Broadway',
#  'Microsoft PhagsPa',
#  'Corbel',
#  'Comic Sans MS',
#  'xkcd',
#  'MT Extra',
#  'Lucida Bright',
#  'Showcard Gothic',
#  'Viner Hand ITC',
#  'Trebuchet MS',
#  'Arial',
#  'Microsoft JhengHei',
#  'Sylfaen',
#  'Lucida Bright',
#  'Consolas',
#  'Sitka',
#  'Leelawadee UI',
#  'Microsoft YaHei',
#  'Comic Sans MS',
#  'Yu Gothic',
#  'Lucida Fax',
#  'Corbel',
#  'Segoe Script',
#  'Arial',
#  'Palatino Linotype',
#  'Times New Roman',
#  'Corbel',
#  'Georgia',
#  'Snap ITC',
#  'Berlin Sans FB Demi',
#  'Franklin Gothic Medium',
#  'Microsoft Sans Serif',
#  'Segoe UI Variable',
#  'Calibri',
#  'SimSun-ExtB',
#  'Freestyle Script',
#  'Microsoft YaHei',
#  'HoloLens MDL2 Assets',
#  'Malgun Gothic',
#  'Monotype Corsiva',
#  'Gabriola',
#  'Arial',
#  'Candara',
#  'Bookman Old Style',
#  'Microsoft Himalaya',
#  'Segoe UI',
#  'Palatino Linotype',
#  'Algerian',
#  'Centaur',
#  'Calibri',
#  'Verdana',
#  'Mistral',
#  'Javanese Text',
#  'Candara',
#  'Bell MT',
#  'Niagara Engraved',
#  'Bauhaus 93',
#  'MingLiU',
#  'Stencil',
#  'Segoe UI',
#  'Matura MT Script Capitals',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Corbel',
#  'Tahoma',
#  'Malgun Gothic',
#  'Gadugi',
#  'Candara',
#  'Microsoft PhagsPa',
#  'Comic Neue',
#  'Segoe UI Historic',
#  'Niagara Solid',
#  'Playbill',
#  'Comic Sans MS',
#  'Century',
#  'Bookshelf Symbol 7',
#  'Webdings',
#  'Arial',
#  'Arial',
#  'Harrington',
#  'Century Gothic',
#  'Constantia',
#  'Microsoft Uighur',
#  'MV Boli']

# %% [markdown]
# ## 測試中文字體Notes:
# ### Mac可用字體：SimHei
# ### Windows 7可用字體：Microsoft YaHei
# ### Windows 10 可用字體：Microsoft JhengHei、DFKai-SB

# %% [markdown]
# # 方法一：更改 plt.rcParams['font.sans-serif'] 設定
# ## Matplotlib example

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='C:/Windows/Fonts/NotoSansCJKtc-Regular.otf')
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 

plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()

# %% [markdown]
# ## Seaborn example

# %%
#from matplotlib.font_manager import FontProperties
import seaborn as sns
sns.set(font=['sans-serif'])
sns.set_style("whitegrid",{"font.sans-serif":['Microsoft JhengHei']})
cities_counter = [('好棒', 285), ('給我', 225), ('不要', 163), ('細柔', 136), ('吃飯', 130), ('小小', 124), ('深圳', 88), ('温州', 67), ('小知', 66), ('大之', 45)]
sns.set_color_codes("pastel")
sns.barplot(x=[k for k, _ in cities_counter[:10]], y=[v for _, v in cities_counter[:10]])
# Out:
# <Axes: >

# %% [markdown]
# # 方法二：更改 plt.rcParams['font.family'] 設定

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(6,4))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.rcParams['font.family']='DFKai-SB' #使用中文字體（黑體）

plt.bar(x,y,align='center')
plt.title('中文標題') #標題名稱
plt.xlabel('X軸') #X軸名稱
plt.ylabel('Y軸') #Y軸名稱
plt.xticks(x, ['刻度A','刻度B','刻度C','刻度D','刻度E']) #X軸刻度名稱

plt.show()

# %% [markdown]
# # 方法三：每次作圖使用特定字體

# %%
seto_font_path = 'C:/Windows/Fonts/SetoFont.ttf'
simsun_font_path = 'C:/Windows/Fonts/SimSun.ttf'
simhei_font_path = 'C:/Windows/Fonts/SimHei.ttf'

font1 = FontProperties(fname=seto_font_path)
font2 = FontProperties(fname=simsun_font_path)
font3 = FontProperties(fname=simhei_font_path)

plt.bar(x,y,align='center')
plt.title('瀨戶字體標題',fontproperties=font1, fontsize=18) #標題名稱
plt.xlabel('新宋字體X軸',fontproperties=font2, fontsize=18) #X軸名稱
plt.ylabel('黑體Y軸',fontproperties=font3, fontsize=18) #Y軸名稱
plt.show()

# %% [markdown]
# # 方法四、自訂字體型式
# ### 下載`.ttf`字體檔，直接指定字體路徑

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='data/微軟正黑體.ttf')

plt.bar((1,2,3),(4,3,-1),align='center')
plt.title('微軟正黑體標題',fontproperties=font, fontsize=18) #標題名稱
plt.xlabel('微軟正黑體X軸',fontproperties=font, fontsize=18) #X軸名稱
plt.ylabel('微軟正黑體Y軸',fontproperties=font, fontsize=18) #Y軸名稱
plt.show()
