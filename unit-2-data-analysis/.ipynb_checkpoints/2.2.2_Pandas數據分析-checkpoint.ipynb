# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv("./data/grades.csv")
df
# Out:
#      姓名  國文  英文  數學  自然  社會
# 0   劉俊安   9  10  15  10  13
# 1   胡玉華  10  10  10   8   9
# 2   黃淑婷  13  15   8  11  14
# 3   陳上紫  10  10   8   9  14
# 4   崔靜成  13  12  14  12  13
# ..  ...  ..  ..  ..  ..  ..
# 95  蔡佳燕   9  10   9  13  14
# 96  吳筱婷   8  10  14  10  15
# 97  陳家銘  14   9  11   8  12
# 98  李明威  15   9   8   9  15
# 99  農揚勇   9  11  12  12  10
#
# [100 rows x 6 columns]

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df['國文']
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()
# Out:
# <Axes: >

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins=15)
# Out:
# <Axes: >

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
print(df.國文.mean())
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
print(df.國文.std())
# Out:
# 2.196852661459484

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
# 顯示 DataFrame
print(df)

# 檢查 DataFrame 的資訊
print(df.info())
# Out:
#      姓名  國文  英文  數學  自然  社會
# 0   劉俊安   9  10  15  10  13
# 1   胡玉華  10  10  10   8   9
# 2   黃淑婷  13  15   8  11  14
# 3   陳上紫  10  10   8   9  14
# 4   崔靜成  13  12  14  12  13
# ..  ...  ..  ..  ..  ..  ..
# 95  蔡佳燕   9  10   9  13  14
# 96  吳筱婷   8  10  14  10  15
# 97  陳家銘  14   9  11   8  12
# 98  李明威  15   9   8   9  15
# 99  農揚勇   9  11  12  12  10
#
# [100 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   姓名      100 non-null    object
#  1   國文      100 non-null    int64
#  2   英文      100 non-null    int64
#  3   數學      100 non-null    int64
#  4   自然      100 non-null    int64
#  5   社會      100 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 4.8+ KB
# None

# %%
# 選擇數字欄位
numeric_df = df.select_dtypes(include=['number'])

# 計算數字欄位的相關性
correlation_matrix = numeric_df.corr()

# 顯示相關性矩陣
correlation_matrix
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
# 國文與數學的相關係數
print(df.國文.corr(df.數學))
# Out:
# -0.3108989822179331

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
# 選擇數字欄位
numeric_columns = df.select_dtypes(include=['number']).columns

# 計算每行的總和，並添加到新col"總級分"
df["總級分"] = df[numeric_columns].sum(axis=1)

# 顯示包含"總級分"的DataFrame
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
# 選擇數字欄位
numeric_columns = df.select_dtypes(include=['number']).columns

# 新col"加權級分"
df["加權級分"] = df.國文+df.英文+df.數學*2

# 顯示包含"加權級分"的DataFrame
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 0  劉俊安   9  10  15  10  13   57    49
# 1  胡玉華  10  10  10   8   9   47    40
# 2  黃淑婷  13  15   8  11  14   61    44
# 3  陳上紫  10  10   8   9  14   51    36
# 4  崔靜成  13  12  14  12  13   64    53

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by = '總級分', ascending=False).head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 12  李正偉  11  15  11  14  15   66    48
# 80  施雅鈴  13  15  12  13  13   66    52
# 37  曾怡君  11  12  15  13  14   65    53
# 25  蔡亦瑄  13  13  14  13  12   65    54
# 54  陳怡潔  15  15   9  15  11   65    48
# 83  李士賢  10  14  15  13  13   65    54
# 87  趙偉希  10  13  14  13  15   65    51
# 64  俞志峰   9  14  13  14  15   65    49
# 48  陳怡婷  15  14  12   9  15   65    53
# 57  胡淳茜  12  15  14  13  11   65    55

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df_rank = df.sort_values(by = ['加權級分','總級分'], ascending=False)

# %%
df_rank.head()
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 73  吳志遠  13  15  15   8   8   59    58
# 57  胡淳茜  12  15  14  13  11   65    55
# 36  詹威德  12  13  15  10  14   64    55
# 25  蔡亦瑄  13  13  14  13  12   65    54
# 83  李士賢  10  14  15  13  13   65    54

# %% [markdown]
# ### 【重點】重設 index

# %%
df_rank.index=range(1,101)
df_rank.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 1  吳志遠  13  15  15   8   8   59    58
# 2  胡淳茜  12  15  14  13  11   65    55
# 3  詹威德  12  13  15  10  14   64    55
# 4  蔡亦瑄  13  13  14  13  12   65    54
# 5  李士賢  10  14  15  13  13   65    54

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df[df.數學=15]
# Out:
#   Cell In[21], line 1
#     df[df.數學=15]
#        ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
df[df.數學==15]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 0   劉俊安   9  10  15  10  13   57    49
# 24  陳竹伯  10  12  15  10  14   61    52
# 36  詹威德  12  13  15  10  14   64    55
# 37  曾怡君  11  12  15  13  14   65    53
# 39  段冠廷   9   8  15  12  15   59    47
# 59  芮秋辛  11  10  15  10   8   54    51
# 67  林哲法  14   9  15  10  14   62    53
# 70  葉儀依   9  13  15   8  14   59    52
# 73  吳志遠  13  15  15   8   8   59    58
# 76  周育霖   9  12  15  13  12   61    51
# 83  李士賢  10  14  15  13  13   65    54
# 85  張雅彬  10  11  15  12   8   56    51
# 90  胡勝傑   8  11  15  10  15   59    49

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df[(df.數學==15) & (df.英文==15)]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 73  吳志遠  13  15  15   8   8   59    58

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
# 刪除col總級分
df_2 = df.drop("總級分", axis=1)

# 按照加權級分進行降序排序
df_2 = df_2.sort_values(by=["加權級分"], ascending=False)

# 重置索引
df_2.index = range(1, len(df_2) + 1)

# 顯示結果
df_2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權級分
# 1  吳志遠  13  15  15   8   8    58
# 2  詹威德  12  13  15  10  14    55
# 3  胡淳茜  12  15  14  13  11    55
# 4  蔡亦瑄  13  13  14  13  12    54
# 5  童心怡  13  13  14   8  13    54

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df = pd.read_csv("./data/grades.csv")

# 選擇數字欄位
numeric_columns = df.select_dtypes(include=['number']).columns

# 新col"總級分"
df["總級分"] = df[numeric_columns].sum(axis=1)
# 新col"加權級分"
df["加權級分"] = df.國文+df.英文+df.數學*2

# 顯示包含"總級分"的DataFrame
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權級分
# 0  劉俊安   9  10  15  10  13   57    49
# 1  胡玉華  10  10  10   8   9   47    40
# 2  黃淑婷  13  15   8  11  14   61    44
# 3  陳上紫  10  10   8   9  14   51    36
# 4  崔靜成  13  12  14  12  13   64    53

# %%
# 複製 DataFrame
df_2 = df.copy()

# 刪除col"總級分"
df_2.drop("總級分", axis=1, inplace=True)

# 按照"加權級分"進行降序排序
df_2.sort_values(by=["加權級分"], ascending=False)

# 重置索引
df_2.index = range(1, len(df) + 1)

# 顯示結果
df_2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權級分
# 1  劉俊安   9  10  15  10  13    49
# 2  胡玉華  10  10  10   8   9    40
# 3  黃淑婷  13  15   8  11  14    44
# 4  陳上紫  10  10   8   9  14    36
# 5  崔靜成  13  12  14  12  13    53

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df_2.head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  加權級分
# 1   劉俊安   9  10  15  10  13    49
# 2   胡玉華  10  10  10   8   9    40
# 3   黃淑婷  13  15   8  11  14    44
# 4   陳上紫  10  10   8   9  14    36
# 5   崔靜成  13  12  14  12  13    53
# 6   張雅岳  13  12  12  12   8    49
# 7   梁俊翔  11  13  10  10  14    44
# 8   林金鳳   8   9  10  10   8    37
# 9   許協旺   9   9  12  10  10    42
# 10  郭雅惠  10  15  12  11   9    49

# %%
df_2.drop(5).head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  加權級分
# 1   劉俊安   9  10  15  10  13    49
# 2   胡玉華  10  10  10   8   9    40
# 3   黃淑婷  13  15   8  11  14    44
# 4   陳上紫  10  10   8   9  14    36
# 6   張雅岳  13  12  12  12   8    49
# 7   梁俊翔  11  13  10  10  14    44
# 8   林金鳳   8   9  10  10   8    37
# 9   許協旺   9   9  12  10  10    42
# 10  郭雅惠  10  15  12  11   9    49
# 11  張志偉  14   9   8  10  12    39

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df_2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權級分
# 1  劉俊安   9  10  15  10  13    49
# 2  胡玉華  10  10  10   8   9    40
# 3  黃淑婷  13  15   8  11  14    44
# 4  陳上紫  10  10   8   9  14    36
# 5  崔靜成  13  12  14  12  13    53

# %%
df_2[df_2.姓名=='劉俊安']
# Out:
#     姓名  國文  英文  數學  自然  社會  加權級分
# 1  劉俊安   9  10  15  10  13    49

# %%
df_2.drop(df_2[df_2.姓名=='劉俊安'].index).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權級分
# 2  胡玉華  10  10  10   8   9    40
# 3  黃淑婷  13  15   8  11  14    44
# 4  陳上紫  10  10   8   9  14    36
# 5  崔靜成  13  12  14  12  13    53
# 6  張雅岳  13  12  12  12   8    49

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import yfinance as yf

# 讀取 Apple (AAPL) 的股票數據
df = yf.download('AAPL')

# 顯示數據
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099058  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093890  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086999  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089152   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091737   73449600

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
# df = pd.read_csv('data/aapl.csv', index_col="Date")

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-300:]
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-03  169.500000  170.919998  167.160004  167.449997  166.335358
# 2023-05-04  164.889999  167.039993  164.309998  165.789993  164.686386
# 2023-05-05  170.979996  174.300003  170.759995  173.570007  172.414612
# 2023-05-08  172.479996  173.850006  172.110001  173.500000  172.345078
# 2023-05-09  173.050003  173.539993  171.600006  171.770004  170.626587
# ...                ...         ...         ...         ...         ...
# 2024-07-08  227.089996  227.850006  223.250000  227.820007  227.820007
# 2024-07-09  227.929993  229.399994  226.369995  228.679993  228.679993
# 2024-07-10  229.300003  233.080002  229.250000  232.979996  232.979996
# 2024-07-11  231.389999  232.389999  225.770004  227.570007  227.570007
# 2024-07-12  228.919998  232.639999  228.679993  230.539993  230.539993
#
#                Volume
# Date
# 2023-05-03   65136000
# 2023-05-04   81235400
# 2023-05-05  113316400
# ...

# %% [markdown]
# #### 20 日的移動平均

# %%
# 繪製收盤價 (Close) 的走勢圖
df.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# 繪製 20 日的移動平均線
df.Close.rolling(20).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values
len(close)
# Out:
# 300

# %%
x = close[:-1]
len(x)
# Out:
# 299

# %%
y = close[1:]
len(y)
# Out:
# 299

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.20942379, -0.06671195, -0.01730015],
#        [-0.40614062,  0.12430267, -0.10604619],
#        [ 0.66635347,  0.4527976 ,  0.54357043],
#        [ 1.60738387,  0.28712703, -0.1820839 ]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0 -0.209424 -0.066712 -0.017300
# 1 -0.406141  0.124303 -0.106046
# 2  0.666353  0.452798  0.543570
# 3  1.607384  0.287127 -0.182084

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0 -0.540098  1.719394 -0.506112
# 1 -1.434394 -0.997980  0.114693
# 2  1.219342  0.966123  1.325121

# %%
df4 = pd.concat([df2,df3],axis=0)

# %%
df4
# Out:
#           A         B         C
# 0 -0.209424 -0.066712 -0.017300
# 1 -0.406141  0.124303 -0.106046
# 2  0.666353  0.452798  0.543570
# 3  1.607384  0.287127 -0.182084
# 0 -0.540098  1.719394 -0.506112
# 1 -1.434394 -0.997980  0.114693
# 2  1.219342  0.966123  1.325121

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(1,len(df4)+1)
df4
# Out:
#           A         B         C
# 1 -0.209424 -0.066712 -0.017300
# 2 -0.406141  0.124303 -0.106046
# 3  0.666353  0.452798  0.543570
# 4  1.607384  0.287127 -0.182084
# 5 -0.540098  1.719394 -0.506112
# 6 -1.434394 -0.997980  0.114693
# 7  1.219342  0.966123  1.325121

# %% [markdown]
# #### 横向的貼

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5 = pd.concat([df2,df3],axis=1)
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.209424 -0.066712 -0.017300 -0.540098  1.719394 -0.506112
# 1 -0.406141  0.124303 -0.106046 -1.434394 -0.997980  0.114693
# 2  0.666353  0.452798  0.543570  1.219342  0.966123  1.325121
# 3  1.607384  0.287127 -0.182084       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv('./data/names.csv', names=['姓名'])
df_names
# Out:
#      姓名
# 0   羅雅慧
# 1   王紹尹
# 2   黃季坤
# 3   許正書
# 4   張鈞蓮
# ..  ...
# 95  陳君生
# 96  曾桂甫
# 97  林欣怡
# 98  林佳霖
# 99  胡筱芸
#
# [100 rows x 1 columns]

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0    6  14   8   6  15
# 1    6  11  12  14   6
# 2    6  13   8   7  12
# 3   11   9  15   6   6
# 4   15  12  13  10  11
# ..  ..  ..  ..  ..  ..
# 95   8  15   7   7  11
# 96   7  10  15  13   9
# 97  11  10  10  15  13
# 98  10   8  10  11   7
# 99   7   6   8   8   9
#
# [100 rows x 5 columns]

# %%
# 將 DataFrame 存成 CSV 檔案，並不保留索引
df_grades.to_csv('./data/grades2', index=0)

# 讀取CSV檔案為DataFrame
df_grades_csv = pd.read_csv('./data/grades2')

# 顯示讀取的DataFrame
df_grades_csv
# Out:
#     國文  英文  數學  社會  自然
# 0    6  14   8   6  15
# 1    6  11  12  14   6
# 2    6  13   8   7  12
# 3   11   9  15   6   6
# 4   15  12  13  10  11
# ..  ..  ..  ..  ..  ..
# 95   8  15   7   7  11
# 96   7  10  15  13   9
# 97  11  10  10  15  13
# 98  10   8  10  11   7
# 99   7   6   8   8   9
#
# [100 rows x 5 columns]

# %%
df_final = pd.concat([df_names, df_grades],axis=1)
df_final
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧   6  14   8   6  15
# 1   王紹尹   6  11  12  14   6
# 2   黃季坤   6  13   8   7  12
# 3   許正書  11   9  15   6   6
# 4   張鈞蓮  15  12  13  10  11
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生   8  15   7   7  11
# 96  曾桂甫   7  10  15  13   9
# 97  林欣怡  11  10  10  15  13
# 98  林佳霖  10   8  10  11   7
# 99  胡筱芸   7   6   8   8   9
#
# [100 rows x 6 columns]

# %%
df_final_2 = pd.concat([df_names, df_grades_csv],axis=1)
df_final_2
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧   6  14   8   6  15
# 1   王紹尹   6  11  12  14   6
# 2   黃季坤   6  13   8   7  12
# 3   許正書  11   9  15   6   6
# 4   張鈞蓮  15  12  13  10  11
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生   8  15   7   7  11
# 96  曾桂甫   7  10  15  13   9
# 97  林欣怡  11  10  10  15  13
# 98  林佳霖  10   8  10  11   7
# 99  胡筱芸   7   6   8   8   9
#
# [100 rows x 6 columns]
