# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x, y)
plt.plot(x, 1.2*x + 0.8, 'r')
plt.show()

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
# 添加噪音
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
y
# Out:
# array([1.30989758, 0.89794586, 0.38780351, 1.06042496, 0.39324151,
#        1.68973358, 1.4793768 , 1.00778687, 1.45621075, 2.58117481,
#        2.03370531, 1.43671276, 2.4336692 , 2.30232185, 1.78680279,
#        3.2153938 , 3.20848205, 3.55882351, 3.6741944 , 3.00970838,
#        3.92975221, 3.72536023, 3.80669745, 3.51501185, 5.11700377,
#        3.75291528, 5.48855415, 3.70490235, 5.19613154, 3.87858727,
#        5.08659007, 3.61814354, 4.86938056, 5.58675057, 3.80774964,
#        5.66677199, 5.98967593, 5.37074633, 4.9212709 , 5.05945545,
#        5.58886194, 5.65178491, 5.8881817 , 5.47725289, 6.64478102,
#        6.62957397, 7.17250383, 7.08711565, 7.0131927 , 6.5982177 ])

# %%
#添加噪音的圖
plt.scatter(x, y)
plt.plot(x, 1.2*x + 0.8, 'r')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %% [markdown]
# `x.reshape(-1, 1)`的主要目的是將一維數組 `x` 轉換為二維數組 `x_reshaped`
#
# 這樣可以符合 sklearn 線性迴歸模型 LinearRegression 的輸入要求
#
# sklearn 的大多數機器學習模型都要求輸入數據是二維數組，即`(n_samples, n_features)`的形狀
#
# 其中 n_samples 是樣本數量，n_features 是特徵數量

# %%
print(x.shape)
x_reshaped = x.reshape(-1, 1)
print(x_reshaped.shape)
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(x_reshaped, y)
# Out:
# LinearRegression()

# %%
y_predict = regr.predict(x_reshaped)
y_predict
# Out:
# array([0.79052051, 0.91724729, 1.04397407, 1.17070084, 1.29742762,
#        1.4241544 , 1.55088118, 1.67760795, 1.80433473, 1.93106151,
#        2.05778828, 2.18451506, 2.31124184, 2.43796862, 2.56469539,
#        2.69142217, 2.81814895, 2.94487572, 3.0716025 , 3.19832928,
#        3.32505606, 3.45178283, 3.57850961, 3.70523639, 3.83196316,
#        3.95868994, 4.08541672, 4.2121435 , 4.33887027, 4.46559705,
#        4.59232383, 4.7190506 , 4.84577738, 4.97250416, 5.09923094,
#        5.22595771, 5.35268449, 5.47941127, 5.60613804, 5.73286482,
#        5.8595916 , 5.98631838, 6.11304515, 6.23977193, 6.36649871,
#        6.49322549, 6.61995226, 6.74667904, 6.87340582, 7.00013259])

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
# 繪製原始數據和預測結果
plt.scatter(x, y, label='Original data')  # 原始數據
plt.plot(x, y_predict, 'ro', label='Fitted line')  # 預測數據

plt.xlabel('x')
plt.ylabel('y_predict')

plt.legend()
plt.show()

# %%
# 計算均方誤差MSE
mse = np.sum((y_predict - y)**2) / len(y)
print("MSE:", mse)
# Out:
# MSE: 0.3415873831479754

# %%
# Y=WX+b

# 獲取模型參數
W = regr.coef_  # 斜率
b = regr.intercept_  # 截距
print("Slope (W):", W)
print("Intercept (b):", b)
# Out:
# Slope (W): [1.24192242]
# Intercept (b): 0.7905205131294588

# %%
# 可以將新的x資料帶入算出結果
# 使用模型進行預測
print("Prediction for x=3:", W * 3 + b)
print("Prediction for x=0.10204082:", W * 0.10204082 + b)
# Out:
# Prediction for x=3: [4.51628776]
# Prediction for x=0.10204082: [0.91724729]

# %%
y_predict
# Out:
# array([0.79052051, 0.91724729, 1.04397407, 1.17070084, 1.29742762,
#        1.4241544 , 1.55088118, 1.67760795, 1.80433473, 1.93106151,
#        2.05778828, 2.18451506, 2.31124184, 2.43796862, 2.56469539,
#        2.69142217, 2.81814895, 2.94487572, 3.0716025 , 3.19832928,
#        3.32505606, 3.45178283, 3.57850961, 3.70523639, 3.83196316,
#        3.95868994, 4.08541672, 4.2121435 , 4.33887027, 4.46559705,
#        4.59232383, 4.7190506 , 4.84577738, 4.97250416, 5.09923094,
#        5.22595771, 5.35268449, 5.47941127, 5.60613804, 5.73286482,
#        5.8595916 , 5.98631838, 6.11304515, 6.23977193, 6.36649871,
#        6.49322549, 6.61995226, 6.74667904, 6.87340582, 7.00013259])

# %%
y
# Out:
# array([1.30989758, 0.89794586, 0.38780351, 1.06042496, 0.39324151,
#        1.68973358, 1.4793768 , 1.00778687, 1.45621075, 2.58117481,
#        2.03370531, 1.43671276, 2.4336692 , 2.30232185, 1.78680279,
#        3.2153938 , 3.20848205, 3.55882351, 3.6741944 , 3.00970838,
#        3.92975221, 3.72536023, 3.80669745, 3.51501185, 5.11700377,
#        3.75291528, 5.48855415, 3.70490235, 5.19613154, 3.87858727,
#        5.08659007, 3.61814354, 4.86938056, 5.58675057, 3.80774964,
#        5.66677199, 5.98967593, 5.37074633, 4.9212709 , 5.05945545,
#        5.58886194, 5.65178491, 5.8881817 , 5.47725289, 6.64478102,
#        6.62957397, 7.17250383, 7.08711565, 7.0131927 , 6.5982177 ])
